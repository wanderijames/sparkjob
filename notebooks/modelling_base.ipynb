# %% [markdown]
# Using https://www.kaggle.com/wendykan/lending-club-loan-data to build a predictive model for dtermining whether a loan application will be charged off.
#
# Our taget column is `loan_status`

# %%
import pyspark
from pyspark.sql import SQLContext
# from pyspark.ml.feature import OneHotEncoderEstimator
from pyspark.sql.functions import udf, col
# from pyspark.sql.types import ArrayType, DoubleType

# %%
sc = pyspark.SparkContext('local[*]')
sc.setCheckpointDir("data_source")
sqc = SQLContext(sc)

# %%
# Get data
df_raw = sqc.read.csv(
    "data_source/lending-club-loan-data/loan.csv.gz",
    header=True, inferSchema=True)
df_raw = df_raw.checkpoint(eager=True)
# Get shape
df_raw.count(), len(df_raw.columns)
# Out:
# (2260668, 145)

# %%
# Analyse the target column
df_t = df_raw.groupBy("loan_status").count().orderBy('count')
df_t.show()
# Out:
# +--------------------+-------+
# |         loan_status|  count|
# +--------------------+-------+
# |            Oct-2015|      1|
# |             Default|     31|
# |Does not meet the...|    761|
# |Does not meet the...|   1988|
# |   Late (16-30 days)|   3737|
# |     In Grace Period|   8952|
# |  Late (31-120 days)|  21897|
# |         Charged Off| 261654|
# |             Current| 919695|
# |          Fully Paid|1041952|
# +--------------------+-------+

# %%
from pyspark.mllib.stat import Statistics
import pandas as pd

def corr(sdf_) -> pd.DataFrame:
    col_names = sdf_.columns
    features = sdf_.rdd.map(lambda row: row[0:])
    corr_mat=Statistics.corr(features, method="pearson")
    corr_df = pd.DataFrame(corr_mat)
    corr_df.index, corr_df.columns = col_names, col_names
    return corr_df

# %%
# Describe the data
df_desc = df_raw.describe()
df_desc_pd = df_desc.toPandas()
df_desc_pd
# Out:
#   summary    id member_id           loan_amnt        funded_amnt  \
# 0   count     0         0             1303606            1303606
# 1    mean  None      None  14416.808280262594   14408.1236777063
# 2  stddev  None      None   8699.544879428344  8695.474688987893
# 3     min  None      None                 500                500
# 4     max  None      None               40000              40000
#
#       funded_amnt_inv        term            int_rate         installment  \
# 0             1303606     1303606             1303606             1303606
# 1  14385.198832128604        None  13.257222941598577  438.08512518353245
# 2   8697.986737787332        None   4.760545049907237   261.0632118093469
# 3                 0.0   36 months                5.31                4.93
# 4             40000.0   60 months               30.99             1719.83
#
#      grade  ... hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0  1303606  ...                           5336                         5336
# 1     None  ...             11028.726163074049           184.57801686972817
# 2     None  ...              7466.642417336538           195.41304080997548
# 3        A  ...                       10008.88                         0.01
# 4        G  ...                              N                            N
#
#   disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 0             1303380              1303435                     32080
# 1                None                 None                      None
# 2                None                 None                      None
# 3                Cash                 Cash                  Apr-2013
# 4           DirectPay                    Y                  Sep-2018
#
#   settlement_status settlement_date  settlement_amount settlement_percentage  \
# 0             32065           32045              32024                 32010
# 1              None            None    5052.1445137391     47.66803963862599
# 2              None            None  3688.425616386922     7.322990784794977
# 3            ACTIVE        Apr-2013               1000                   0.2
# 4                 N        Sep-2018                  N                     N
#
#       settlement_term
# 0               32006
# 1  13.091844071399544
# 2   8.280573985586306
# 3                   0
# 4                   N
#
# [5 rows x 146 columns]

# %%
# Select only rows whose `loan_status` value is in ["Fully Paid", "Charged Off"]
df_raw = df_raw.filter((df_raw["loan_status"] == "Fully Paid") | (df_raw["loan_status"] == "Charged Off"))

# %%
cols_to_drop_1 = ["id", "member_id", "pymnt_plan", "url"]

# %%
selected_columns_1 = [x for x in df_raw.columns if x not in cols_to_drop_1]

# %%
def is_null_column(df_: pd.DataFrame, column: str, num_rows_: int, threshold: float = 0.8) -> bool:
    """If column values has more than the threshold null"""
    _df = df_.groupBy(column).count().orderBy('count')
    _df = _df.where(col(column).isNull()).select("count")
    try:
        frequency = float(_df.collect()[0][0])
        return (frequency / num_rows_) > threshold
    except IndexError:
        return False

# %%
from pyspark.sql.functions import countDistinct

# d = df_raw.agg(countDistinct("desc").alias('desc')).collect()

# %%
# Reduce dataframe

# %%
# Drop null value rows and duplicates row-wise
na_thresh = int(0.7 * len(selected_columns_1)) # 70% threshold
df_raw = df_raw.drop(*cols_to_drop_1).dropna(thresh=na_thresh).dropDuplicates()

# %%
# cols_to_drop_2 = [col for col in df_raw.columns if is_null_column(df_raw, col, num_rows, 0.7)]
cols_to_drop_2 = ['desc', 'mths_since_last_record', 'next_pymnt_d', 'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'mths_since_recent_bc_dlq', 'revol_bal_joint', 'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il', 'sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog', 'hardship_type', 'hardship_reason', 'hardship_status', 'deferral_term', 'hardship_amount', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date', 'hardship_length', 'hardship_dpd', 'hardship_loan_status', 'orig_projected_additional_accrued_interest', 'hardship_payoff_balance_amount', 'hardship_last_payment_amount', 'debt_settlement_flag_date', 'settlement_status', 'settlement_date', 'settlement_amount', 'settlement_percentage', 'settlement_term']

# %%
df_raw = df_raw.drop(*cols_to_drop_2)
df_raw = df_raw.checkpoint(eager=True)

# Get shape
# num_rows = df_raw4.count()
len(df_raw.columns)
# Out:
# 102

# %%
df_raw.limit(5).toPandas()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       6950         6950           6950.0   36 months      5.32       209.30
# 1       9600         9600           9600.0   36 months     12.79       322.50
# 2      10425        10425          10425.0   60 months     25.29       307.77
# 3      27675        27675          27675.0   36 months     18.25      1004.00
# 4       2000         2000           2000.0   36 months     15.49        69.82
#
#   grade sub_grade emp_title emp_length  ... percent_bc_gt_75  \
# 0     A        A1      None        n/a  ...             12.5
# 1     C        C1      None        n/a  ...              9.1
# 2     E        E5      None        n/a  ...             25.0
# 3     D        D3      None        n/a  ...             40.0
# 4     C        C4      None        n/a  ...             33.3
#
#   pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# 0                    0         0          408936             38049
# 1                    0         0          175600             21313
# 2                    0         0           43434             11803
# 3                    0         0           48844             28458
# 4                    0         0          651850             78053
#
#   total_bc_limit total_il_high_credit_limit hardship_flag disbursement_method  \
# 0          71200                      22436             N                Cash
# 1          81900                          0             N                Cash
# 2          14500                          0             N                Cash
# 3          24600                      15000             N                Cash
# 4          53000                      68087             N                Cash
#
#   debt_settlement_flag
# 0                    N
# 1                    N
# 2                    N
# 3                    Y
# 4                    N
#
# [5 rows x 102 columns]

# %%
cols_to_drop_3 = ["emp_title", "emp_length"]
df_raw = df_raw.drop(*cols_to_drop_3)
len(df_raw.columns)
# Out:
# 100

# %%
feature_columns = df_raw.columns[:-1]
"loan_status" not in feature_columns
# Out:
# False

# %%
# See distinct columns
str_columns_ = [col[0] for col in df_raw.dtypes if col[1] == "string"]
non_str_columns = [col[0] for col in df_raw.dtypes if col[1] != "string"]

# %%
import pandas as pd

cols_ = df_raw.columns
df_pd_uniq1 = pd.DataFrame(
    index=str_columns_,
    columns=["num_distinct"],
    data=(df_raw.select(col).distinct().count() for col in str_columns_)
)

# %%
# unqs = df_pd_uniq1.sort_values("num_distinct", axis=0, ascending=True).to_dict()["num_distinct"]
unqs = {"term":2,"policy_code":2,"out_prncp_inv":2,"out_prncp":2,"loan_status":2,"hardship_flag":3,"application_type":3,"disbursement_method":3,"initial_list_status":3,"debt_settlement_flag":3,"verification_status":3,"home_ownership":5,"acc_now_delinq":6,"grade":7,"inq_last_6mths":8,"collections_12_mths_ex_med":13,"purpose":14,"open_il_12m":20,"open_acc_6m":20,"delinq_2yrs":25,"open_rv_12m":28,"inq_fi":32,"open_il_24m":32,"pub_rec":32,"sub_grade":35,"last_credit_pull_d":41,"last_pymnt_d":45,"inq_last_12m":45,"open_rv_24m":47,"open_act_il":51,"addr_state":51,"total_cu_tl":55,"title":66,"issue_d":74,"open_acc":78,"total_acc":132,"mths_since_last_delinq":147,"all_util":171,"il_util":232,"mths_since_rcnt_il":334,"earliest_cr_line":696,"zip_code":914,"revol_util":1176,"bc_util":1276,"total_rec_late_fee":6764,"dti":6859,"tot_coll_amt":8815,"total_rev_hi_lim":11635,"max_bal_bc":26954,"annual_inc":29736,"recoveries":51743,"collection_recovery_fee":54244,"avg_cur_bal":61117,"revol_bal":62052,"total_rec_prncp":90304,"total_bal_il":115314,"tot_cur_bal":258722,"total_rec_int":276554,"last_pymnt_amnt":345672,"total_pymnt_inv":439404,"total_pymnt":475538}
unqs
# Out:
# {'term': 2,
#  'policy_code': 2,
#  'out_prncp_inv': 2,
#  'out_prncp': 2,
#  'loan_status': 2,
#  'hardship_flag': 3,
#  'application_type': 3,
#  'disbursement_method': 3,
#  'initial_list_status': 3,
#  'debt_settlement_flag': 3,
#  'verification_status': 3,
#  'home_ownership': 5,
#  'acc_now_delinq': 6,
#  'grade': 7,
#  'inq_last_6mths': 8,
#  'collections_12_mths_ex_med': 13,
#  'purpose': 14,
#  'open_il_12m': 20,
#  'open_acc_6m': 20,
#  'delinq_2yrs': 25,
#  'open_rv_12m': 28,
#  'inq_fi': 32,
#  'open_il_24m': 32,
#  'pub_rec': 32,
#  'sub_grade': 35,
#  'last_credit_pull_d': 41,
#  'last_pymnt_d': 45,
#  'inq_last_12m': 45,
#  'open_rv_24m': 47,
#  'open_act_il': 51,
#  'addr_state': 51,
#  'total_cu_tl': 55,
#  'title': 66,
#  'issue_d': 74,
#  'open_acc': 78,
#  'total_acc': 132,
#  'mths_since_last_delinq': 147,
#  'all_util': 171,
#  'il_util': 232,
#  'mths_since_rcnt_il': 334,
#  'earliest_cr_line': 696,
#  'zip_code': 914,
#  'revol_util': 1176,
#  'bc_util': 1276,
#  'total_rec_late_fee': 6764,
#  'dti': 6859,
#  'tot_coll_amt': 8815,
#  'total_rev_hi_lim': 11635,
#  'max_bal_bc': 26954,
#  'annual_inc': 29736,
#  'recoveries': 51743,
#  'collection_recovery_fee': 54244,
#  'avg_cur_bal': 61117,
#  'revol_bal': 62052,
#  'total_rec_prncp': 90304,
#  'total_bal_il': 115314,
#  'tot_cur_bal': 258722,
#  'total_rec_int': 276554,
#  'last_pymnt_amnt': 345672,
#  'total_pymnt_inv': 439404,
#  'total_pymnt': 475538}

# %%
str_col_to_double = [k for k,v in unqs.items() if (int(v) > 1000)]

# %%
category_cols = [k for k,v in unqs.items() if (int(v) <= 10 )]

# %%
category_cols
# Out:
# ['term',
#  'policy_code',
#  'out_prncp_inv',
#  'out_prncp',
#  'loan_status',
#  'hardship_flag',
#  'application_type',
#  'disbursement_method',
#  'initial_list_status',
#  'debt_settlement_flag',
#  'verification_status',
#  'home_ownership',
#  'acc_now_delinq',
#  'grade',
#  'inq_last_6mths']

# %%
df_train = df_raw.selectExpr(*non_str_columns, *category_cols, *["cast({col} as float) {col}".format(col=col) for col in str_col_to_double])
df_train = df_train.checkpoint(eager=True)

# %%
len(df_train.columns)
# Out:
# 73

# %%
"loan_status" in category_cols
# Out:
# True

# %%
# from pyspark.sql.functions import when

# df_train2 = df_train.withColumn("label", \
#               when(df_train["loan_status"] == "Charged Off", 1).otherwise(0))

# %%
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer, VectorAssembler
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

df_corr = df_train.select(*df_train.columns)
for col_ in category_cols:
    indexer_ = StringIndexer(inputCol=col_, outputCol="indexed{}".format(col_))
    indexer_.setHandleInvalid("skip")
    model_ = indexer_.fit(df_corr)
    df_corr = model_.transform(df_corr)

corr_columns = non_str_columns + str_col_to_double + ["indexed{}".format(col_) for col_ in category_cols]
df_corr = df_corr.select(*corr_columns)  
corred_df = corr(df_corr)
corred_df
# Out:
#                             loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# loan_amnt                    1.000000     1.000000         0.999993  0.153055
# funded_amnt                  1.000000     1.000000         0.999993  0.153055
# funded_amnt_inv              0.999993     0.999993         1.000000  0.153071
# int_rate                     0.153055     0.153055         0.153071  1.000000
# installment                  0.954716     0.954716         0.954625  0.194181
# ...                               ...          ...              ...       ...
# indexedverification_status   0.078608     0.078608         0.078589  0.108396
# indexedhome_ownership       -0.122259    -0.122259        -0.122287  0.053858
# indexedacc_now_delinq       -0.000809    -0.000809        -0.000831  0.005909
# indexedgrade                 0.116410     0.116410         0.116314  0.539518
# indexedinq_last_6mths       -0.011623    -0.011623        -0.011685  0.191889
#
#                             installment  acc_open_past_24mths  bc_open_to_buy  \
# loan_amnt                      0.954716              0.013086             NaN
# funded_amnt                    0.954716              0.013086             NaN
# funded_amnt_inv                0.954625              0.013038             NaN
# int_rate                       0.194181              0.201701             NaN
# installment                    1.000000              0.033065             NaN
# ...                                 ...                   ...             ...
# indexedverification_status     0.086530              0.049892             NaN
# indexedhome_ownership         -0.098394             -0.048185             NaN
# indexedacc_now_delinq          0.001750             -0.007716             NaN
# indexedgrade                   0.159332              0.084502             NaN
# indexedinq_last_6mths          0.012099              0.303644             NaN
#
#                             chargeoff_within_12_mths  delinq_amnt  \
# loan_amnt                                  -0.004334     0.001007
# funded_amnt                                -0.004334     0.001007
# funded_amnt_inv                            -0.004345     0.001000
# int_rate                                    0.008882     0.003152
# installment                                -0.002219     0.002017
# ...                                              ...          ...
# indexedverification_status                  0.005364     0.008051
# indexedhome_ownership                      -0.003110     0.000595
# indexedacc_now_delinq                       0.037271     0.180353
# indexedgrade                               -0.004734    -0.002251
# indexedinq_last_6mths                       0.010896    -0.000751
#
#                             mo_sin_old_il_acct  ...  indexedhardship_flag  \
# loan_amnt                                  NaN  ...             -0.001020
# funded_amnt                                NaN  ...             -0.001020
# funded_amnt_inv                            NaN  ...             -0.001019
# int_rate                                   NaN  ...             -0.002187
# installment                                NaN  ...             -0.001045
# ...                                        ...  ...                   ...
# indexedverification_status                 NaN  ...             -0.001516
# indexedhome_ownership                      NaN  ...             -0.001283
# indexedacc_now_delinq                      NaN  ...             -0.000099
# indexedgrade                               NaN  ...              0.000532
# indexedinq_last_6mths                      NaN  ...              0.000653
#
#                             indexedapplication_type  \
# loan_amnt                                  0.107950
# funded_amnt                                0.107950
# funded_amnt_inv                            0.107956
# int_rate                                   0.053495
# installment                                0.095152
# ...                                             ...
# indexedverification_status                 0.063065
# indexedhome_ownership                     -0.066372
# indexedacc_now_delinq                     -0.005686
# indexedgrade                               0.016400
# indexedinq_last_6mths                     -0.029348
#
#                             indexeddisbursement_method  \
# loan_amnt                                     0.006530
# funded_amnt                                   0.006530
# funded_amnt_inv                               0.006499
# int_rate                                      0.010670
# installment                                   0.004520
# ...                                                ...
# indexedverification_status                    0.015337
# indexedhome_ownership                         0.005588
# indexedacc_now_delinq                        -0.003885
# indexedgrade                                  0.042829
# indexedinq_last_6mths                        -0.005148
#
#                             indexedinitial_list_status  \
# loan_amnt                                    -0.066785
# funded_amnt                                  -0.066785
# funded_amnt_inv                              -0.067611
# int_rate                                      0.154123
# installment                                   0.003629
# ...                                                ...
# indexedverification_status                    0.017394
# indexedhome_ownership                         0.032240
# indexedacc_now_delinq                         0.001364
# indexedgrade                                  0.116577
# indexedinq_last_6mths                         0.051262
#
#                             indexeddebt_settlement_flag  \
# loan_amnt                                      0.005112
# funded_amnt                                    0.005112
# funded_amnt_inv                                0.005053
# int_rate                                       0.068833
# installment                                    0.009841
# ...                                                 ...
# indexedverification_status                     0.020613
# indexedhome_ownership                          0.021992
# indexedacc_now_delinq                          0.000796
# indexedgrade                                   0.037265
# indexedinq_last_6mths                          0.018878
#
#                             indexedverification_status  indexedhome_ownership  \
# loan_amnt                                     0.078608              -0.122259
# funded_amnt                                   0.078608              -0.122259
# funded_amnt_inv                               0.078589              -0.122287
# int_rate                                      0.108396               0.053858
# installment                                   0.086530              -0.098394
# ...                                                ...                    ...
# indexedverification_status                    1.000000              -0.024063
# indexedhome_ownership                        -0.024063               1.000000
# indexedacc_now_delinq                         0.013290              -0.007412
# indexedgrade                                  0.072646               0.008554
# indexedinq_last_6mths                         0.028876               0.000009
#
#                             indexedacc_now_delinq  indexedgrade  \
# loan_amnt                               -0.000809      0.116410
# funded_amnt                             -0.000809      0.116410
# funded_amnt_inv                         -0.000831      0.116314
# int_rate                                 0.005909      0.539518
# installment                              0.001750      0.159332
# ...                                           ...           ...
# indexedverification_status               0.013290      0.072646
# indexedhome_ownership                   -0.007412      0.008554
# indexedacc_now_delinq                    1.000000     -0.004600
# indexedgrade                            -0.004600      1.000000
# indexedinq_last_6mths                   -0.002920      0.089317
#
#                             indexedinq_last_6mths
# loan_amnt                               -0.011623
# funded_amnt                             -0.011623
# funded_amnt_inv                         -0.011685
# int_rate                                 0.191889
# installment                              0.012099
# ...                                           ...
# indexedverification_status               0.028876
# indexedhome_ownership                    0.000009
# indexedacc_now_delinq                   -0.002920
# indexedgrade                             0.089317
# indexedinq_last_6mths                    1.000000
#
# [73 rows x 73 columns]

# %%
corred_df = corr(df_corr)

# %%
import math
d = corred_df["indexedloan_status"].to_dict()
cols_to_drop_4 = [k.replace("indexed", "") for k,v in d.items() if math.isnan(v)]
cols_to_drop_4
# Out:
# ['bc_open_to_buy',
#  'mo_sin_old_il_acct',
#  'mths_since_recent_bc',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_tl_120dpd_2m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'revol_util',
#  'bc_util',
#  'dti',
#  'max_bal_bc',
#  'avg_cur_bal',
#  'total_bal_il',
#  'policy_code',
#  'out_prncp_inv',
#  'out_prncp']

# %%
df_train3 = df_train.drop(*cols_to_drop_4)
final_features = [x for x in df_train3.columns if x != "loan_status"]
len(final_features)
# Out:
# 55

# %%
"loan_status" in final_features
# Out:
# False

# %%
df_train3.dtypes
# Out:
# [('loan_amnt', 'int'),
#  ('funded_amnt', 'int'),
#  ('funded_amnt_inv', 'double'),
#  ('int_rate', 'double'),
#  ('installment', 'double'),
#  ('acc_open_past_24mths', 'int'),
#  ('chargeoff_within_12_mths', 'double'),
#  ('delinq_amnt', 'int'),
#  ('mo_sin_old_rev_tl_op', 'int'),
#  ('mo_sin_rcnt_rev_tl_op', 'int'),
#  ('mo_sin_rcnt_tl', 'int'),
#  ('mort_acc', 'int'),
#  ('num_accts_ever_120_pd', 'int'),
#  ('num_actv_bc_tl', 'int'),
#  ('num_actv_rev_tl', 'int'),
#  ('num_bc_sats', 'int'),
#  ('num_bc_tl', 'int'),
#  ('num_il_tl', 'int'),
#  ('num_op_rev_tl', 'int'),
#  ('num_rev_accts', 'int'),
#  ('num_rev_tl_bal_gt_0', 'int'),
#  ('num_sats', 'int'),
#  ('num_tl_30dpd', 'int'),
#  ('num_tl_90g_dpd_24m', 'int'),
#  ('num_tl_op_past_12m', 'int'),
#  ('pub_rec_bankruptcies', 'int'),
#  ('tax_liens', 'int'),
#  ('tot_hi_cred_lim', 'int'),
#  ('total_bal_ex_mort', 'int'),
#  ('total_bc_limit', 'int'),
#  ('total_il_high_credit_limit', 'int'),
#  ('term', 'string'),
#  ('loan_status', 'string'),
#  ('hardship_flag', 'string'),
#  ('application_type', 'string'),
#  ('disbursement_method', 'string'),
#  ('initial_list_status', 'string'),
#  ('debt_settlement_flag', 'string'),
#  ('verification_status', 'string'),
#  ('home_ownership', 'string'),
#  ('acc_now_delinq', 'string'),
#  ('grade', 'string'),
#  ('inq_last_6mths', 'string'),
#  ('total_rec_late_fee', 'float'),
#  ('tot_coll_amt', 'float'),
#  ('total_rev_hi_lim', 'float'),
#  ('annual_inc', 'float'),
#  ('recoveries', 'float'),
#  ('collection_recovery_fee', 'float'),
#  ('revol_bal', 'float'),
#  ('total_rec_prncp', 'float'),
#  ('tot_cur_bal', 'float'),
#  ('total_rec_int', 'float'),
#  ('last_pymnt_amnt', 'float'),
#  ('total_pymnt_inv', 'float'),
#  ('total_pymnt', 'float')]

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer, VectorAssembler
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

cols_to_index = [k for k,v in df_train3.dtypes if (v == "string" and k != "loan_status")]
non_to_index = [k for k,v in df_train3.dtypes if v != "string"]
df_trainx = df_train3.select(*df_train3.columns)
for col_ in cols_to_index:
    indexer_ = StringIndexer(inputCol=col_, outputCol="indexed{}".format(col_))
    indexer_.setHandleInvalid("skip")
    model_ = indexer_.fit(df_trainx)
    df_trainx = model_.transform(df_trainx)
    
columns = non_to_index + ["indexed{}".format(col_) for col_ in cols_to_index]
    
assembler = VectorAssembler(inputCols=columns, outputCol="features", handleInvalid="skip")
df_train3 = assembler.transform(df_trainx)


# Index labels, adding metadata to the label column.
# Fit on whole dataset to include all labels in index.
labelIndexer = StringIndexer(inputCol="loan_status", outputCol="indexedloan_status", handleInvalid="skip")
labelIndexer.setHandleInvalid("skip")
labelIndexer = labelIndexer.fit(df_train)

# Automatically identify categorical features, and index them.
# Set maxCategories so features with > 4 distinct values are treated as continuous.
featureIndexer =\
     VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=len(cols_to_index), handleInvalid="skip")
featureIndexer.setHandleInvalid("skip")


# Split the data into training and test sets (30% held out for testing)
(trainingData, testData) = df_train3.randomSplit([0.7, 0.3])

# Train a RandomForest model.
rf = RandomForestClassifier(
    labelCol="indexedloan_status",
    featuresCol="indexedFeatures",
    predictionCol="prediction",
    numTrees=10)

# # Convert indexed labels back to original labels.
labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=labelIndexer.labels)

# Chain indexers and forest in a Pipeline
pipeline = Pipeline(stages=[labelIndexer, featureIndexer, rf, labelConverter])

# Train model.  This also runs the indexers.
model = pipeline.fit(trainingData)

# Make predictions.
predictions = model.transform(testData)

# Select example rows to display.
predictions.select("predictedLabel", "loan_status", "features").show(5)

# Select (prediction, true label) and compute test error
evaluator = MulticlassClassificationEvaluator(
    labelCol="indexedloan_status", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Test Error = %g" % (1.0 - accuracy))

rfModel = model.stages[2]
print(rfModel)  # summary only
# Out:
# +--------------+-----------+--------------------+
# |predictedLabel|loan_status|            features|
# +--------------+-----------+--------------------+
# |    Fully Paid| Fully Paid|[1000.0,1000.0,95...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|[1000.0,1000.0,10...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,8,...|
# |    Fully Paid| Fully Paid|[1000.0,1000.0,10...|
# +--------------+-----------+--------------------+
# only showing top 5 rows
#
# Test Error = 0.01928
# RandomForestClassificationModel (uid=RandomForestClassifier_9ff182238118) with 10 trees

# %%
predictions.select("predictedLabel", "loan_status", "features").show(50)
# Out:
# +--------------+-----------+--------------------+
# |predictedLabel|loan_status|            features|
# +--------------+-----------+--------------------+
# |    Fully Paid| Fully Paid|[1000.0,1000.0,95...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|[1000.0,1000.0,10...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,8,...|
# |    Fully Paid| Fully Paid|[1000.0,1000.0,10...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |   Charged Off|Charged Off|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|[1400.0,1400.0,14...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |   Charged Off|Charged Off|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|[1900.0,1900.0,18...|
# |    Fully Paid| Fully Paid|[2000.0,2000.0,20...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|[2000.0,2000.0,20...|
# |    Fully Paid| Fully Paid|[2000.0,2000.0,20...|
# |    Fully Paid|Charged Off|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|[2200.0,2200.0,22...|
# |   Charged Off|Charged Off|[2375.0,2375.0,23...|
# |    Fully Paid|Charged Off|[2400.0,2400.0,23...|
# |    Fully Paid| Fully Paid|[2400.0,2400.0,24...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |   Charged Off|Charged Off|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|[2500.0,2500.0,25...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|[2800.0,2800.0,28...|
# |   Charged Off|Charged Off|[2800.0,2800.0,28...|
# |    Fully Paid| Fully Paid|[2800.0,2800.0,28...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|[3000.0,3000.0,30...|
# |    Fully Paid| Fully Paid|[3000.0,3000.0,30...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|[3000.0,3000.0,30...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |   Charged Off|Charged Off|[3000.0,3000.0,30...|
# |   Charged Off|Charged Off|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,8,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|(55,[0,1,2,3,4,5,...|
# |    Fully Paid| Fully Paid|[3000.0,3000.0,30...|
# +--------------+-----------+--------------------+
# only showing top 50 rows

# %%
cols_dropped = cols_to_drop_4 + cols_to_drop_3 + cols_to_drop_2 + cols_to_drop_1
cols_dropped
# Out:
# ['bc_open_to_buy',
#  'mo_sin_old_il_acct',
#  'mths_since_recent_bc',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_tl_120dpd_2m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'revol_util',
#  'bc_util',
#  'dti',
#  'max_bal_bc',
#  'avg_cur_bal',
#  'total_bal_il',
#  'policy_code',
#  'out_prncp_inv',
#  'out_prncp',
#  'emp_title',
#  'emp_length',
#  'desc',
#  'mths_since_last_record',
#  'next_pymnt_d',
#  'mths_since_last_major_derog',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'mths_since_recent_bc_dlq',
#  'revol_bal_joint',
#  'sec_app_earliest_cr_line',
#  'sec_app_inq_last_6mths',
#  'sec_app_mort_acc',
#  'sec_app_open_acc',
#  'sec_app_revol_util',
#  'sec_app_open_act_il',
#  'sec_app_num_rev_accts',
#  'sec_app_chargeoff_within_12_mths',
#  'sec_app_collections_12_mths_ex_med',
#  'sec_app_mths_since_last_major_derog',
#  'hardship_type',
#  'hardship_reason',
#  'hardship_status',
#  'deferral_term',
#  'hardship_amount',
#  'hardship_start_date',
#  'hardship_end_date',
#  'payment_plan_start_date',
#  'hardship_length',
#  'hardship_dpd',
#  'hardship_loan_status',
#  'orig_projected_additional_accrued_interest',
#  'hardship_payoff_balance_amount',
#  'hardship_last_payment_amount',
#  'debt_settlement_flag_date',
#  'settlement_status',
#  'settlement_date',
#  'settlement_amount',
#  'settlement_percentage',
#  'settlement_term',
#  'id',
#  'member_id',
#  'pymnt_plan',
#  'url']
